# %% [markdown]
# <a href="https://colab.research.google.com/github/JangYuSeung/My_ML_Course_Notebook/blob/main/250930_Linear_Regression_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Import module (코드 수정 X)

# %%
import pandas as pd
import numpy as np
import math


from sklearn.model_selection import train_test_split

# %% [markdown]
# #### download dataset (코드 수정 X)

# %%
# Load dataset file
# !wget "https://dongaackr-my.sharepoint.com/:x:/g/personal/sjkim_donga_ac_kr/EYMXYk25h2VBtPXtu3QaBqoBJK4cK-TI9mamHoFGJRYn5Q?e=8x2MTn&download=1" -O modified_uber.csv
data = pd.read_csv('modified_uber.csv')
data = data.drop(['Unnamed: 0.1', 'Unnamed: 0', 'key'], axis=1)
data = data.dropna()
data
# Out:
# --2025-10-13 12:20:55--  https://dongaackr-my.sharepoint.com/:x:/g/personal/sjkim_donga_ac_kr/EYMXYk25h2VBtPXtu3QaBqoBJK4cK-TI9mamHoFGJRYn5Q?e=8x2MTn&download=1
# Resolving dongaackr-my.sharepoint.com (dongaackr-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8f8::10, ...
# Connecting to dongaackr-my.sharepoint.com (dongaackr-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/sjkim_donga_ac_kr/Documents/%ea%b3%b5%ec%9c%a0%ec%9e%90%eb%a3%8c/modified_uber.csv?ga=1 [following]
# --2025-10-13 12:20:56--  https://dongaackr-my.sharepoint.com/personal/sjkim_donga_ac_kr/Documents/%ea%b3%b5%ec%9c%a0%ec%9e%90%eb%a3%8c/modified_uber.csv?ga=1
# Reusing existing connection to dongaackr-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29662084 (28M) [application/octet-stream]
# Saving to: ‘modified_uber.csv’
#
# modified_uber.csv   100%[===================>]  28.29M  8.78MB/s    in 3.2s
#
# 2025-10-13 12:20:59 (8.78 MB/s) - ‘modified_uber.csv’ saved [29662084/29662084]
#         fare_amount          pickup_datetime   pickup_x   pickup_y  \
# 0               7.5  2015-05-07 19:52:06 UTC  26.801401  31.975242
# 1               7.7  2009-07-17 20:04:56 UTC  76.052494  88.508509
# 2              12.9  2009-08-24 21:45:00 UTC  15.267869  43.955819
# 3               5.3  2009-06-26 08:22:21 UTC  20.332390  62.963745
# 4              16.0  2014-08-28 17:47:00 UTC  55.287436   0.890515
# ...             ...                      ...        ...        ...
# 199994          3.0  2012-10-28 10:49:00 UTC  84.707837  88.315857
# 199995          7.5  2014-03-14 01:09:00 UTC  89.307465  90.446660
# 199996         30.9  2009-06-29 00:42:00 UTC  11.018380  10.443077
# 199997         14.5  2015-05-20 14:56:25 UTC  55.104242  33.397616
# 199998         14.1  2010-05-15 04:08:00 UTC  62.020770  27.142860
#
#          dropoff_x   dropoff_y  passenger_count
# 0        82.753859   78.351728                1
# 1       116.105293   92.327957                1
# 2        65.431587   61.653900                1
# 3        32.219453  119.648762                3
# 4       128.745703   53.748090                5
# ...            ...         ...              ...
# 199994  119.137618  110.819151                1
# 199995  148.777837  101.245691                1
# 199996   45.211427   35.886442                2
# 199997   96.482991  103.718360                1
# 199998   86.086272   50.534788                1
#
# [199999 rows x 7 columns]

# %% [markdown]
# #### Data 전처리 (코드 수정 X)

# %%
data_numpy = np.array(data)

# 임시 입력 data 설정
x = np.zeros((data_numpy.shape[0], 3))
y = data_numpy[:, 0]

# 좌표값을 사용하여 거리로 변환
Delta_x = data_numpy[:, 4] - data_numpy[:, 2] # dropoff_x - pickup_x
Delta_y = data_numpy[:, 5] - data_numpy[:, 3] # dropoff_y - pickup_y
# L1 distance 저장
x[:, 0] = np.abs(Delta_x)+np.abs(Delta_y) # 델타x + 델타y

# %% [markdown]
# #### 거리 data 전처리

# %%
# 좌표값을 사용하여 거리로 변환
Delta_x = data_numpy[:, 4] - data_numpy[:, 2] # dropoff_x - pickup_x
Delta_y = data_numpy[:, 5] - data_numpy[:, 3] # dropoff_y - pickup_y
# L1 distance 저장
x[:, 0] = np.abs(Delta_x)+np.abs(Delta_y) # 델타x + 델타y

# L2 distance 저장
x[:, 1] = np.sqrt(Delta_x**2 + Delta_y**2 )

# 승객 수 저장
x[:, 2] = data_numpy[:, -1]

# %% [markdown]
# #### Data min-max 정규화

# %%
# x에 대한 min, max값 도출
x_min =
x_max =

# y에 대한 min, max값 도출
y_min =
y_max =

# 정규화 수행
x =
y =

# %% [markdown]
# #### Linear model 작성

# %%
class LSM():
  def __init__(self):
    self.theta = None

  def fit(self, X, Y):
    N = X.shape[0] # N = 입력 데이터 개수

    # 입력 X에 대해 bias 차원 추가
    bias = np.ones((N, 1))
    X = np.hstack([X, bias])

    # Least Square Method 수행
    # X transpose 생성

    # X^T * X 생성

    # (X^T * X)^-1 생성

    # X^T * Y 생성

    # theta 계산
    self.theta =
    return self.theta

  def predict(self, X):
    N = X.shape[0] # N = 입력 데이터 개수

    # 입력 X에 대해 bias 차원 추가
    bias = np.ones((N, 1))
    X = np.hstack([X, bias])

    # 저장된 theta와 X를 이용하여 Y_hat 계산
    Y_hat = np.dot(X, self.theta)
    return Y_hat

# %% [markdown]
# #### weight, bias 학습 (코드 수정 X)

# %%
linear_model = LSM()
theta = linear_model.fit(x, y)
print(theta)

# %% [markdown]
# #### 가격 예측

# %%
l1_distance = 250
l2_distance = 180.277
passenger_count_test = 2

input_test = np.hstack([l1_distance, l2_distance, passenger_count_test])

# 신규 데이터 정규화 (데이터 전처리에서 사용한 min, max값 이용)
input_test =

price_test = linear_model.predict(input_test)

# 출력 데이터 역정규화 (데이터 전처리에서 사용한 min, max값 이용)
price_test =

print(price_test)
